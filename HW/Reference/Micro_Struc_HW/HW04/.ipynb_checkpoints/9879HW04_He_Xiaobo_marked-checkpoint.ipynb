# %% [markdown]
# # Xiaobo He <font color='blue'> Score: 26/38 </font>
#
# #### <font color='blue'> Please see the corresponding cells for comments (in blue) on each individual question, if there's any. </font>

# %% [markdown]
# # MTH9879 Homework 4
#
# Assigned: March 8, 2016.
# Due: March 22, 2016 by 6pm.
#
# Late homework **will not be accepted**.
#
# $$
# \newcommand{\underbar}{\underline}
# \newcommand{\supp}{\mathrm{supp}}
# \newcommand{\E}{\mathbb{E}}
# \newcommand{\EE}{\mathbb{E}}
# \newcommand{\Eof}[1]{\mathbb{E}\left[ #1 \right]}
# \def\Cov{{ \mbox{Cov} }}
# \def\Var{{ \mbox{Var} }}
# \newcommand{\1}{\mathbf{1} }
# \newcommand{\PP}{\mathbb{P} }
# %\newcommand{\Pr}{\mathrm{Pr} }
# \newcommand{\QQ}{\mathbb{Q} }
# \newcommand{\RR}{\mathbb{R} }
# \newcommand{\DD}{\mathbb{D} }
# \newcommand{\HH}{\mathbb{H} }
# \newcommand{\spn}{\mathrm{span} }
# \newcommand{\cov}{\mathrm{cov} }
# \newcommand{\sgn}{\mathrm{sgn} }
# \newcommand{\HS}{\mathcal{L}_{\mathrm{HS}} }
# %\newcommand{\HS}{\mathrm{HS} }
# \newcommand{\trace}{\mathrm{trace} }
# \newcommand{\LL}{\mathcal{L} }
# %\newcommand{\LL}{\mathrm{L} }
# \newcommand{\s}{\mathcal{S} }
# \newcommand{\ee}{\mathcal{E} }
# \newcommand{\ff}{\mathcal{F} }
# \newcommand{\hh}{\mathcal{H} }
# \newcommand{\bb}{\mathcal{B} }
# \newcommand{\dd}{\mathcal{D} }
# \newcommand{\g}{\mathcal{G} }
# \newcommand{\p}{\partial}
# \newcommand{\half}{\frac{1}{2} }
# \newcommand{\T}{\mathcal{T} }
# \newcommand{\bi}{\begin{itemize}}
# \newcommand{\ei}{\end{itemize}}
# \newcommand{\beq}{\begin{equation}}
# \newcommand{\eeq}{\end{equation}}
# \newcommand{\beas}{\begin{eqnarray*}}
# \newcommand{\eeas}{\end{eqnarray*}}
# \newcommand{\cO}{\mathcal{O}}
# \newcommand{\cF}{\mathcal{F}}
# \newcommand{\cL}{\mathcal{L}}
# \newcommand{\BS}{\text{BS}}
# $$

# %% [markdown]
# <font color = "red">Homework is to be done by each student individually.  To receive full credit, you must email a completed copy of this iPython notebook to Tai-Ho Wang (tai-ho.wang@baruch.cuny.edu) and Jim Gatheral (jim.gatheral@baruch.cuny.edu) by the due date and time.  All R-code must run correctly and solutions must be written up neatly in Markdown/LaTeX format.
#
# <font color="blue">If you encounter problems with Markdown/LaTeX or iPython notebook, please contact Yuxi Liu, who has kindly offered to help.

# %% [markdown]
# ### 0. (0 points)
# Read Chapter 5 and 6 of Hasbrouck and Chapters 2 and 3 of Foucault, Pagano and R&ouml;ell.

# %% [markdown]
# ## Glosten and Milgrom

# %% [markdown]
# ### 1. (8 points) <font color=blue> Score: 8/8 </font>
#
# (Adapted from Hasbrouck 5.2 but please note that the setup in (3) in the slides is different from Hasbrouck's in Figure 5.1 of his book.) Consider a variant of the Glosten and Milgrom model where there is informed trading only in the low state $V=\underline V$.
#
# (a) Show that the learned probability after one step that the true price is $\bar V$ is given by
#
# $$
# \delta_1(Buy)=\Pr(\bar V|Buy)=\frac{\delta}{1-\mu\,(1-\delta)};\quad \delta_1(Sell)=\Pr(\bar V|Sell)=\frac{\delta}{1+\mu\,(1-\delta)}
# $$
#
# and that
#
# $$
# A=\frac{\underline V\,{(1-\delta)\,(1-\mu)}+\bar V\,{\delta}}{{1-\mu\,(1-\delta)}};\quad B=\frac{\underline V\,{(1-\delta)\,(1+\mu)}+\bar V\,{\delta}}{1+\mu\,(1-\delta)}
# $$
#
# (b) Deduce an expression for the spread $s=A-B$.
#
# (c) Explain the sensitivities of the spread to the parameters of the model to a non-expert.

# %% [markdown]
# ### 1. Solution
# ### (a)
#
# $$\delta_1(Buy)=\Pr(\bar V|\text{Buy})
# =\frac{\Pr(\bar V \cap \text{Buy})}{\Pr(\text{Buy})}
# =\frac{\frac 12 \delta}{\frac 12[1-\mu(1-\delta)]}
# =\frac{\delta}{1-\mu\,(1-\delta)}$$
#
#
#
# $$\delta_1(Sell)=\Pr(\bar V|\text{Sell})
# =\frac{\Pr(\bar V \cap \text{Sell})}{\Pr(\text{Sell})}
# =\frac{\frac 12 \delta}{\frac 12 [1+\mu(1-\delta)]}
# =\frac{\delta}{1+\mu\,(1-\delta)}$$
#
# $$\Pr(\underline V|Buy)=1-\Pr(\bar V|\text{Buy})=\frac{(1-\delta)(1-\mu)}{1-\mu(1-\delta)}$$
#
# $$\Pr(\underline V|Sell)=1-\Pr(\bar V|\text{Sell})=\frac{(1-\delta)(1+\mu)}{1-\mu(1-\delta)}$$
#
# $$A = \mathbb{E} [V|Buy] = {\bar V\,\Pr(\bar V|Buy)+\underline V\,\Pr(\underline V|Buy)} = \frac{\underline V(1-\delta)(1-\mu)+\bar V\delta}{1-\mu(1-\delta)} $$
#
# $$B= \mathbb{E} [V|Sell] = {\bar V\,\Pr(\bar V|Sell)+\underline V\,\Pr(\underline V|Sell)}= \frac{\underline V\,{(1-\delta)\,(1+\mu)}+\bar V\,{\delta}}{1+\mu\,(1-\delta)}$$
#
# ### (b)
#
# The spread:
# $$ s = A-B =  \frac{\underline V(1-\delta)(1-\mu)+\bar V\delta}{1-\mu(1-\delta)} - \frac{\underline V\,{(1-\delta)\,(1+\mu)}+\bar V\,{\delta}}{1+\mu\,(1-\delta)} = \frac{2\delta\mu(1-\delta)(\bar V - \underline V)}{1-\mu^2(\delta-1)^2} $$
#
# ### (c)
# The spread will increase as $(\bar V - \underline V)$ increases, as a result to compensate the higher risk associated with larger difference between $\bar V$ and $\underline V$.
#
# Spread will decrease as $\delta$ increases which means there is more "adverse selection" in the $\underline V$ stage.
#
# Spread will increase as $\mu$ increase because more informed trading in the market and market maker needs larger compensation with bigger spread.

# %% [markdown]
# ### Load data and R packages for the next questions

# %%
download.file(url="http://mfe.baruch.cuny.edu/wp-content/uploads/2015/02/tq.zip", destfile="tq.zip")
unzip(zipfile="tq.zip")

# %%
load('tq.rData')
#check if some necessary packages are installed
#if not, install them
#options(repos=structure(c(CRAN="http://cran.at.r-project.org/")))
#list.of.packages <- c("highfrequency","quantmod")
#new.packages <- 
#list.of.packages[!(list.of.packages %in% installed.packages()[,"Package"])]
#if(length(new.packages)) install.packages(new.packages)
#include the libraries
library(highfrequency)
library(xts)
library(quantmod)

# %% [markdown]
# ## The Lee and Ready tick test

# %% [markdown]
# ### 2. (10 points) <font color=blue> Score: 8/10 </font>
#
# In the following use the trades and quotes object *tqBAC* in the loaded data *tq.rData*.  Denote trade prices by $p_t$ and mid-quotes by $m_t$.
#
# (a) Compute the time series of trade signs $\epsilon_t$ according to $\epsilon_t=+1$ if $p_t>m_t$ and  $\epsilon_t=-1$ otherwise, using the Lee-Ready rule for trades at mid.  Name this series *tradeSigns*. (Note this was already done in the lecture.)
#
# (b) Compute the Lee-Ready trade-sign indicator time series (as if you didn't have quotes and so no mid-prices).
#
# (c) Compute the correlation of these two indicators.
#
# (d) Assume the rule in part (a) is 100% accurate.  What percentage of trades are correctly signed by the Lee-Ready test?
#
# (e) Explain the relationship between your answers in (c) and (d).

# %% [markdown]
# ### 2. Solution

# %%
#(a)
#Time series of trade signs
tradeSigns <- getTradeDirection(tqBAC)

# %%
#(b)
#Lee-Ready trade-sign indicator time series
price <- as.numeric(tqBAC$PRICE)
len_price <- length(price)
indicator <- rep(0,length(price))
indicator[1] <- 1

for(i in 2:len_price){
    if (price[i] > price[i-1])
        indicator[i] <- 1
    else if (price[i] < price[i-1])
        indicator[i] <- -1
    else
        indicator[i] <- indicator[i-1]   
}

# %%
#(c)
#Correlation of these two indicators
corr <- cor(indicator, tradeSigns)
sprintf("Correlation of these two indicators is: %s", corr)
# Out:
# [1] "Correlation of these two indicators is: 0.661734963254114"

# %%
#(d)
#Percentage of trades are correctly signed by the Lee-Ready test
counter_diff <- 0

for (i in 1:len_price){
    if (indicator[i] != tradeSigns[i])
        counter_diff <- counter_diff + 1
}
    
percent <- 1-counter_diff/len_price
sprintf ("Percentage of trades are correctly signed by the Lee-Ready test: %s", percent)
# Out:
# [1] "Percentage of trades are correctly signed by the Lee-Ready test: 0.829656176503528"

# %% [markdown]
# ### (e)
# When the percentage of trades correctly signed are higher, the correlation is higher. It is cosistent with (c) and(d) since the correlation is not 1.
#
# <br>
# <font color=blue>(2pt off) Notice that, by the computation above, if we let $p \approx 83\%$ be the correct percentange and $\rho \approx 66\%$ as the correlation, then the two quantities are related by $\rho \approx 2p - 1$. How so? </font>

# %% [markdown]
# ## Realized spread by exchange

# %% [markdown]
# ### 3. (8 points) <font color=blue> Score: 4/8 </font>
#
# (a) Reproduce Figure 6 from the lecture slides, making sure to get the aesthetics right.
#
# (b) Explain why the realized spread profile varies by exchange.
#
# (c) Redo the picture adjusting for the following (assumed) take fees:
#
# ** Exchange ** | ** Take fee **
# --- | ---
# | (**cents**)
# D | 0.10
# B | -0.04
# Z | 0.29
# Y | 0.00
# P | 0.25
#
# (d) Based on your results, where would you advise sending a small market order?  How about a large one?

# %% [markdown]
# ### 3. Solution

# %%
#(a)
# Generate rsLag
rsLag <- function(exch) {
    set <- subset(tqBAC, tqBAC$EX==exch)
    mids <- (as.numeric(set$OFR) + as.numeric(set$BID))/2
    price <- as.numeric(set$PRICE)
    len_price <- length(price)
    tradeSigns <- getTradeDirection(set)
    rs <- function(lag){mean(tradeSigns[1:(len_price-lag)]*(price[1:(len_price-lag)]-mids[-(1:lag)]))}
    rsLag <- sapply(1:50,rs)
    return (rsLag)
}

# create rsLags for different exchanges
rsLag_D <- rsLag('D')
rsLag_B <- rsLag('B')
rsLag_Z <- rsLag('Z')
rsLag_Y <- rsLag('Y')
rsLag_P <- rsLag('P')

#Plot the figures
plot(x=1:50,y=rsLag_D,col="red",type="l",xlab=expression(tau), ylab = "Realized spread", ylim=c(-0.003, 0.008))
lines(x=1:50,y=rsLag_B,col="blue")
lines(x=1:50,y=rsLag_Z,col="orange")
lines(x=1:50,y=rsLag_Y,col="purple")
lines(x=1:50,y=rsLag_P,col="green")
legend("topleft", 
       c("D-FINRA",
         "B-NASDAQ OMX BX",
         "Z-BATS Exchange",
         "Y-BATS Y-Exchange",
         "P-NYSE Arca SM"),
       lty = c(1,1,1,1,1), 
       col=c("red","blue","yellow","purple","green"))

abline(h=0, lty=2, lwd=2)
# Out:
# plot without title

# %% [markdown]
# <font color=blue>(2pts off) The plot above is pretty off from the figure in the lecture. It even shows negative spreads.

# %% [markdown]
# ### (b)
# The reason for why the realized spread profile varies by exchange is that different exchanges have difference fee structure, which will cause different transaction costs.
#
# <br>
# <font color=blue> Exchanges with higher take fees and higher make rebates should have greater adverse selection of limit orders.  Realized spreads on these exchanges should therefore be lower. </font>

# %%
#(c)
#Redo the picture adjusting for the assumed take fees
plot(x=1:50,y=rsLag_D+0.001*2,col="red",type="l",xlab=expression(tau), ylab = "Realized spread", ylim=c(-0.003, 0.012))
lines(x=1:50,y=rsLag_B-0.0004*2,col="blue")
lines(x=1:50,y=rsLag_Z+0.0029*2,col="orange")
lines(x=1:50,y=rsLag_Y,col="purple")
lines(x=1:50,y=rsLag_P+0.0025*2,col="green")

legend("topleft", 
       c("D-FINRA",
         "B-NASDAQ OMX BX",
         "Z-BATS Exchange",
         "Y-BATS Y-Exchange",
         "P-NYSE Arca SM"),
       lty = c(1,1,1,1,1), 
       col=c("red","blue","yellow","purple","green"))

abline(h=0, lty=2, lwd=2)
# Out:
# plot without title

# %% [markdown]
# <font color=blue>(2pts off) Same here. The plot is off.

# %% [markdown]
# ### (d)
# For a small market order, we care about fee, then we would like to choose B-NASDAQ OMX BX exchange; for a large market order, it will take more time to execute, then we would like to choose Y-BATS Y Exchange.

# %% [markdown]
# ## Predicting trade signs

# %% [markdown]
# ### 4. (6 points) <font color=blue> Score: 6/6 </font>
#
# The following require the *tradeSigns* series from Problem 2.
#
# (a) Denote the probability of a sign reversal by $\pi$.  Derive an expression in terms of $\pi$ for the conditional expectation $\E[\epsilon_t|\epsilon_{t-1}]$.
#
# (b) Assume zero expectation of the trading signs, fit an AR(1) model to the series *tradeSigns*.  What is the coefficient returned by this model?  Explain how  this coefficient relates to $\pi$?

# %% [markdown]
# ### 4. Solution
# ### (a)
# The conditional expectation $\E[\epsilon_t|\epsilon_{t-1}]$ in terms of $\pi$:
# $$\mathbb{E} [\epsilon_t|\epsilon_{t-1}] = \epsilon_{t-1}(1-\pi) - \epsilon_{t-1}\pi = \epsilon_{t-1}(1-2\pi) $$

# %%
#(b)
tradeSigns <- getTradeDirection(tqBAC) 
epsilon_t <- tradeSigns[1:(length(tradeSigns)-1)]
epsilon_t_1 <- tradeSigns[2:length(tradeSigns)]

df_tradeSigns <- data.frame(epsilon_t, epsilon_t_1)
df_tradeSigns.lm <- lm(epsilon_t ~ epsilon_t_1, data=df_tradeSigns)
pi_empirical <- (1 - coefficients(df_tradeSigns.lm)[2])/2.0

sprintf("Coefficient: %s", coefficients(df_tradeSigns.lm)[2])
sprintf("Empirical pi: %s",pi_empirical)
# Out:
# [1] "Coefficient: 0.0815349169590274"
# [1] "Empirical pi: 0.459232541520486"

# %% [markdown]
# Since $\epsilon_t = \rho\epsilon_{t-1} + \omega_t$, $\mathbb{E} [\epsilon_t|\epsilon_{t-1}] =\epsilon_{t-1}(1-2\pi)$, we have $\rho \approx 1-2\pi$.
#
# Here we get:
#
# $\rho = 0.0815349169590317$
#
#
# $\pi = 0.459232541520484$

# %% [markdown]
# ## The MRR model

# %% [markdown]
# ### 5. (6 points) <font color=blue> Score: 0/6 </font>
# Using the estimate of $\rho$ (the coefficient obtained from fitting to an AR(1) model) from Problem 4 and equation (11) from the lecture slides:
#
# $$
# \Delta p_t=(\phi+\lambda)\,\epsilon_t-(\phi+\rho\,\lambda)\,\epsilon_{t-1}+e_t+\Delta \xi_t
# $$
#
# estimate by linear regression the MRR parameters $\phi$ (transaction cost) and $\lambda$ (adverse selection or "Kyle lambda") from  *tqBAC*.  This amounts to ignoring the autocorrelation of the $\Delta \xi_t$.
# <br>
#
# Hint: Use the R function *lm*  to perform the linear regressions.

# %%
df_tradeSigns <- data.frame(tradeSigns[1:(length(tradeSigns)-1)], tradeSigns[2:length(tradeSigns)], price[2:len]-price[1:(len-1)])
df_tradeSigns.lm <- lm((price[2:len]-price[1:(len-1)]) ~ tradeSigns[1:(length(tradeSigns)-1)] + tradeSigns[2:length(tradeSigns)], data=df_tradeSigns)

df_tradeSigns.lm$coeff[2]
df_tradeSigns.lm$coeff[3]
# Out:
# Error in data.frame(tradeSigns[1:(length(tradeSigns) - 1)], tradeSigns[2:length(tradeSigns)], : object 'len' not found
# Error in eval(expr, envir, enclos): object 'len' not found
# epsilon_t_1
#  0.08153492
# <NA>
#   NA

# %% [markdown]
# <font color=blue> Code can't run. See the error message above.

# %% [markdown]
# Therefore, we have
# $$ \phi + \lambda = -0.00233674861617547 $$
# $$ -(\phi + \rho\lambda) = 0.00287693836375597 $$
# since we know that $\rho = 0.081529782863637$,
#
# we have
# $$\lambda = 0.000588141$$
# $$\phi = -0.002924889$$
